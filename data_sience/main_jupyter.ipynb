# %%
import pandas as pd # type: ignore

# %%
dados = pd.read_csv('fifa/players_15.csv')

# %%
dados
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
# BUSCA O DOIS PRIMEIROS CAMPOS

dados.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
#
#    height_cm  weight_kg nationality          club  ...   lwb   ldm   cdm  \
# 0        169         67   Argentina  FC Barcelona  ...  62+3  62+3  62+3
# 1        185         80    Portugal   Real Madrid  ...  63+3  63+3  63+3
#
#     rdm   rwb    lb   lcb    cb   rcb    rb
# 0  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1  63+3  63+3  57+3  52+3  52+3  52+3  57+3
#
# [2 rows x 104 columns]

# %%
# BUSCA OS DOIS ÚLTIMOS CAMPOS

dados.tail(2)
# Out:
#        sofifa_id                                         player_url  \
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#        short_name     long_name  age         dob  height_cm  weight_kg  \
# 15463   T. Davies    Tom Davies   22  1992-04-18        180         70
# 15464  P. Tisdale  Paul Tisdale   41  1973-01-14        175         72
#
#       nationality            club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 15463     England  Fleetwood Town  ...  37+0  36+0  36+0  36+0  37+0  39+0
# 15464       Malta     Exeter City  ...  36+0  37+0  37+0  37+0  36+0  34+0
#
#         lcb    cb   rcb    rb
# 15463  40+0  40+0  40+0  39+0
# 15464  33+0  33+0  33+0  34+0
#
# [2 rows x 104 columns]

# %%
# BUSCA O NOME DAS COLUNAS

dados.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
# BUSCA AS LINHAS

dados.index
# Out:
# RangeIndex(start=0, stop=15465, step=1)

# %%
# BUSCA SOMENTE A LISTA DE (short_name e age)

dados[['short_name', 'age']]
# Out:
#               short_name  age
# 0               L. Messi   27
# 1      Cristiano Ronaldo   29
# 2              A. Robben   30
# 3         Z. Ibrahimović   32
# 4               M. Neuer   28
# ...                  ...  ...
# 15460          E. Redman   17
# 15461         A. Collins   17
# 15462           P. Żemło   18
# 15463          T. Davies   22
# 15464         P. Tisdale   41
#
# [15465 rows x 2 columns]

# %%
# BUSCA AS ENTRADAS ESPECIFICADAS DENTRO DO []

dados.iloc[0:4]
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# 0        169         67    Argentina         FC Barcelona  ...  62+3  62+3
# 1        185         80     Portugal          Real Madrid  ...  63+3  63+3
# ...

# %%
dados.iloc[3,3]
# Out:
# 'Zlatan Ibrahimović'

# %%
# LOCALIZA APENAS OS DADOS QUE BATEM COM AS INFORMAÇÕES ESPECIFICADAS 

dados.loc[dados['nationality'] == 'Brazil']
# Out:
#        sofifa_id                                         player_url  \
# 15        164240  https://sofifa.com/player/164240/thiago-emilia...
# 19        190871  https://sofifa.com/player/190871/neymar-da-sil...
# 47        188152  https://sofifa.com/player/188152/oscar-dos-san...
# 86        146530  https://sofifa.com/player/146530/daniel-alves-...
# 93        168609  https://sofifa.com/player/168609/joao-miranda-...
# ...          ...                                                ...
# 12809     221685  https://sofifa.com/player/221685/pedro-nezio-a...
# 13476     224957  https://sofifa.com/player/224957/andre-quemelo...
# 14345     225549  https://sofifa.com/player/225549/darlan-bispo-...
# 14721     223431  https://sofifa.com/player/223431/rafael-leandr...
# 15246     224181  https://sofifa.com/player/224181/lucas-guedes-...
#
#           short_name                            long_name  age         dob  \
# ...

# %%
# BUSCA DE ACORDO COM A ORDEM ALFABÉTICA OU ORDEM DOS NÚMEROS

dados.sort_values('age')
# Out:
#        sofifa_id                                         player_url  \
# 15304     225292  https://sofifa.com/player/225292/edoardo-togna...
# 12000     215400  https://sofifa.com/player/215400/hakon-lorentz...
# 14066     225237  https://sofifa.com/player/225237/jacob-ortmark...
# 14729     224915  https://sofifa.com/player/224915/scott-wright/...
# 14194     225490  https://sofifa.com/player/225490/frederik-bay/...
# ...          ...                                                ...
# 468        11983  https://sofifa.com/player/11983/brad-friedel/1...
# 15455      11728  https://sofifa.com/player/11728/barry-richards...
# 15282     168706  https://sofifa.com/player/168706/paul-mathers/...
# 3676      136594  https://sofifa.com/player/136594/byung-ji-kim/...
# 10504     188492  https://sofifa.com/player/188492/andrea-pierob...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# ...

# %%
# USANDO (ascending = False), ELE BUSCA DO MAIOR PARA O MENOR (Tanto para Número quanto para Letra)

dados.sort_values('age', ascending= False)
# Out:
#        sofifa_id                                         player_url  \
# 3676      136594  https://sofifa.com/player/136594/byung-ji-kim/...
# 10504     188492  https://sofifa.com/player/188492/andrea-pierob...
# 15282     168706  https://sofifa.com/player/168706/paul-mathers/...
# 15455      11728  https://sofifa.com/player/11728/barry-richards...
# 468        11983  https://sofifa.com/player/11983/brad-friedel/1...
# ...          ...                                                ...
# 10874     225163  https://sofifa.com/player/225163/david-munoz-p...
# 15007     215502  https://sofifa.com/player/215502/bartlomiej-dr...
# 15005     222454  https://sofifa.com/player/222454/niall-flint/1...
# 15030     222322  https://sofifa.com/player/222322/george-poynto...
# 15033     225487  https://sofifa.com/player/225487/hasan-kurucay...
#
#           short_name             long_name  age         dob  height_cm  \
# 3676    Kim Byung Ji      김병지 Byung Ji Kim   44  1970-04-08        184
# ...

# %%
# ADICIONANDO UMA COLUNA (total)

dados['total'] = dados['movement_acceleration'] + dados['movement_agility'] + dados['movement_reactions']
dados
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
dados = dados[['short_name', 'total']]
dados.sort_values('total', ascending= False)
# Out:
#           short_name     total
# 157       T. Walcott    978382
# 7242        M. Bolly    977366
# 0           L. Messi  969494-2
# 335    P. Aubameyang  968181-1
# 7966        D. Oduro  96+29058
# ...              ...       ...
# 6112        R. Zajac    204153
# 13572      S. Sjanic    203749
# 11872         C. Day    203453
# 4327      R. Carroll    202764
# 8718        K. Baran    202548
#
# [15465 rows x 2 columns]

# %%
# EXPORTANDO OS DADOS (dados.1csv)

dados.to_csv('dados1.csv', index= False)

# %%
# EXPORTANDO OS DADOS DE OUTRA MANEIRA (dado2.xlsx)

dados.to_excel('dados2.xlsx', index= False)

# %%
# EXPORTANDO OS DADOS DE OUTRA MANEIRA (dado3.txt)

dados.to_csv('dados3.txt', index= False, sep='\t') # sep - Usado para tirar a vírgula, melhorando a forma de ler.
